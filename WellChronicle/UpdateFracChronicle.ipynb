# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('FF_data')
print("connected to sqlite3 verion:", sqlite3.version)
# Out:
# connected to sqlite3 verion: 2.6.0

# %%
lastChronicle = pd.read_sql_query(
     """SELECT *
              
       from fracChronicle"""
     , conn)

# %%
lastChronicle.tail()
# Out:
#              APINumber                  OperatorName              JobEndDate  \
# 173914  37015217420000           EOG Resources, Inc.  10/14/2020 12:00:00 AM
# 173915  37015219880000           EOG Resources, Inc.  10/14/2020 12:00:00 AM
# 173916  42173346750000               Berry Petroleum   5/23/2021 12:00:00 AM
# 173917  42115334560000     Pioneer Natural Resources    6/8/2021 12:00:00 AM
# 173918  42227368950000  Meritage Energy Company, LLC    4/1/3012 12:00:00 AM
#
#           pullDate
# 173914  2020-10-18
# 173915  2020-10-18
# 173916  2020-10-18
# 173917  2020-10-18
# 173918  2020-10-18

# %%
lastUpdate = pd.read_sql_query(
     """SELECT APINumber
              ,OperatorName
              ,JobEndDate
              
        from RegistryUpload"""
       ,conn)

# %%
lastUpdate['pullDate'] = pd.to_datetime('today').date()
lastUpdate = lastUpdate.drop_duplicates().reset_index(drop=True)
lastUpdate.tail()
# Out:
#              APINumber                     OperatorName  \
# 174023  05071084630000  Evergreen Natural Resources LLC
# 174024  42283370210000       Chesapeake Operating, Inc.
# 174025  42173346750000                  Berry Petroleum
# 174026  42115334560000        Pioneer Natural Resources
# 174027  42227368950000     Meritage Energy Company, LLC
#
#                    JobEndDate    pullDate
# 174023  10/21/2020 6:00:00 AM  2020-10-25
# 174024  10/22/2020 1:51:56 AM  2020-10-25
# 174025  5/23/2021 12:00:00 AM  2020-10-25
# 174026   6/8/2021 12:00:00 AM  2020-10-25
# 174027   4/1/3012 12:00:00 AM  2020-10-25

# %%
df_all = lastChronicle.merge(lastUpdate.drop_duplicates(), on=['APINumber','JobEndDate'], 
                   how='outer', indicator=True)

# %%
df_all = df_all.drop_duplicates().reset_index(drop=True)
df_all.head()
# Out:
#         APINumber                 OperatorName_x              JobEndDate  \
# 0  49009219470000     Chesapeake Operating, Inc.   5/19/1982 12:00:00 AM
# 1  49009228850000     Chesapeake Operating, Inc.    2/7/1995 12:00:00 AM
# 2  42335355480000  Energen Resources Corporation   6/11/1996 12:00:00 AM
# 3  42395313840000          XTO Energy/ExxonMobil  12/13/2001 12:00:00 AM
# 4  37059247370000             CONSOL Energy Inc.   9/22/2008 12:00:00 AM
#
#    pullDate_x                 OperatorName_y  pullDate_y _merge
# 0  2020-10-18     Chesapeake Operating, Inc.  2020-10-25   both
# 1  2020-10-18     Chesapeake Operating, Inc.  2020-10-25   both
# 2  2020-10-18  Energen Resources Corporation  2020-10-25   both
# 3  2020-10-18          XTO Energy/ExxonMobil  2020-10-25   both
# 4  2020-10-18             CONSOL Energy Inc.  2020-10-25   both

# %%
fracChronicle = df_all[['APINumber','JobEndDate']].copy()
fracChronicle['OperatorName'] = df_all['OperatorName_x'].fillna(df_all['OperatorName_y'])
fracChronicle['pullDate'] = df_all['pullDate_x'].fillna(df_all['pullDate_y'])
fracChronicle['pullDate'] = pd.to_datetime(fracChronicle['pullDate'])
fracChronicle = fracChronicle.drop_duplicates().reset_index(drop=True)

# %%
fracChronicle.tail(2)
# Out:
#              APINumber             JobEndDate  \
# 174028  05071084630000  10/21/2020 6:00:00 AM
# 174029  42283370210000  10/22/2020 1:51:56 AM
#
#                            OperatorName   pullDate
# 174028  Evergreen Natural Resources LLC 2020-10-25
# 174029       Chesapeake Operating, Inc. 2020-10-25

# %%
fracsDropped = df_all[(df_all['_merge'] == 'left_only')]
fracsDropped
# Out:
#              APINumber                   OperatorName_x            JobEndDate  \
# 141913  05123426480000                Whiting Petroleum  4/30/2018 4:55:05 PM
# 143188  05123457080000  HighPoint Operating Corporation  5/25/2018 6:00:00 AM
#
#         pullDate_x OperatorName_y pullDate_y     _merge
# 141913  2020-10-18            NaN        NaN  left_only
# 143188  2020-10-18            NaN        NaN  left_only

# %%
fracsAdded = fracChronicle[fracChronicle['pullDate'] == '2020-10-25']
fracsAdded
# Out:
#              APINumber             JobEndDate  \
# 173919  35071248800000   1/29/2018 6:00:00 AM
# 173920  05123426480000   4/30/2018 6:00:00 AM
# 173921  05123461340000   2/28/2019 7:00:00 AM
# 173922  42341005830000  5/15/2019 12:00:00 AM
# 173923  42421006130000  5/16/2019 12:00:00 AM
# ...                ...                    ...
# 174025  30015466000000  10/16/2020 5:00:00 AM
# 174026  33053081160000  10/16/2020 5:00:00 AM
# 174027  05071092650000  10/19/2020 6:00:00 AM
# 174028  05071084630000  10/21/2020 6:00:00 AM
# 174029  42283370210000  10/22/2020 1:51:56 AM
#
#                            OperatorName   pullDate
# 173919             Blue Ox Partners LLC 2020-10-25
# 173920                Whiting Petroleum 2020-10-25
# 173921          Crestone Peak Resources 2020-10-25
# 173922            Scout Energy Partners 2020-10-25
# 173923            Scout Energy Partners 2020-10-25
# ...                                 ...        ...
# 174025                COG Operating LLC 2020-10-25
# 174026               Petro Hunt, L.L.C. 2020-10-25
# 174027  Evergreen Natural Resources LLC 2020-10-25
# 174028  Evergreen Natural Resources LLC 2020-10-25
# 174029       Chesapeake Operating, Inc. 2020-10-25
#
# [111 rows x 4 columns]

# %%
fracChronicle.to_sql('fracChronicle', conn, index=False, if_exists='replace')

# %%
conn.close()
